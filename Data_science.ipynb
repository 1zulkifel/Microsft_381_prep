# %%
import numpy as np
A = np.random.randn(4,3)
B = np.sum(A, axis = 1, keepdims = True)
print(B)
# Out:
# [[ 3.4374421 ]
#  [-3.76338576]
#  [-0.79205471]
#  [-0.05042509]]

# %% [markdown]
# # Visualizing Data

# %%
from matplotlib import pyplot as plt
years=[1950,1960,1970,1980,1990,2000]
gdp=[10,20,15,39,22,60]
plt.plot(years,gdp,color='green', marker="d",linestyle='solid')
plt.title("pak gdp")
plt.ylabel("Billion of ruppees")
plt.xlabel("years")

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
